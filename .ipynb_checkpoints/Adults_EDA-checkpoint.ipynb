# %% [markdown]
# # Analisis Exploratorio de Datos

# %% [markdown]
# ---
# Alumno: Angel Alonso Galarza Chavez <br>
# Materia: Mineria de Datos <br>
# Docente: Dra. Xiaoou Li
#
# ---

# %%
# Bibliotecas para el manejo de los datos y la graficacion
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Biblioteca para el preprocesamiento de los datos
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Analisis Exploratorio de Datos

# %% [markdown]
# ### Cargando el Dataset

# %%
# Lista con los nombres de las caracteristicas
adults_name = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation',
'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'target']

adults_name
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'target']

# %%
# Con la biblioteca pandas para manejo de datos, se cargan los datos del dataset Iris a la variable df_iris
df_income = pd.read_csv('adult/adult.data', names=adults_name, header=None)
df_income.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# Con la biblioteca pandas para manejo de datos, se cargan los datos del dataset Iris a la variable df_iris
df_income_test = pd.read_csv('adult/adult.test', names=adults_name, header=None)
df_income_test['target'] = df_income_test['target'].replace([' <=50K.', ' >50K.'], [' <=50K', ' >50K'])
df_income_test.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country  target
# 0             0              40   United-States   <=50K
# 1             0              50   United-States   <=50K
# 2             0              40   United-States    >50K
# 3             0              40   United-States    >50K
# 4             0              30   United-States   <=50K

# %%
df_income = pd.concat([df_income_train, df_income_test], axis = 0)
df_income.reset_index(drop=True, inplace=True)
df_income
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 48837   39            Private  215419   Bachelors             13
# 48838   64                  ?  321403     HS-grad              9
# 48839   38            Private  374983   Bachelors             13
# 48840   44            Private   83891   Bachelors             13
# 48841   35       Self-emp-inc  182148   Bachelors             13
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# 1       Married-civ-spouse     Exec-managerial          Husband
# 2                 Divorced   Handlers-cleaners    Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners          Husband
# 4       Married-civ-spouse      Prof-specialty             Wife
# ...                    ...                 ...              ...
# 48837             Divorced      Prof-specialty    Not-in-family
# 48838              Widowed                   ?   Other-relative
# 48839   Married-civ-spouse      Prof-specialty          Husband
# 48840             Divorced        Adm-clerical        Own-child
# 48841   Married-civ-spouse     Exec-managerial          Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# ...                    ...      ...           ...           ...
# 48837                White   Female             0             0
# 48838                Black     Male             0             0
# 48839                White     Male             0             0
# 48840   Asian-Pac-Islander     Male          5455             0
# 48841                White     Male             0             0
#
#        hours-per-week  native-country  target
# 0                  40   United-States   <=50K
# 1                  13   United-States   <=50K
# 2                  40   United-States   <=50K
# 3                  40   United-States   <=50K
# 4                  40            Cuba   <=50K
# ...               ...             ...     ...
# 48837              36   United-States   <=50K
# 48838              40   United-States   <=50K
# 48839              50   United-States   <=50K
# 48840              40   United-States   <=50K
# 48841              60   United-States    >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# #### Convirtiendo los valores del atributo Target a 0 y 1

# %%
# Utilizando la funcion Label Encoder
label_encoder = LabelEncoder()

# Transformando el atributo Target
df_income['target'] = label_encoder.fit_transform(df_income['target'])
df_income.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States       0
# 1             0             0              13   United-States       0
# 2             0             0              40   United-States       0
# 3             0             0              40   United-States       0
# 4             0             0              40            Cuba       0

# %% [markdown]
# Como el conjunto de datos df_income_test tiene en el atributo 'target' valores con espacios, estos se eliminaran

# %%
df_income_test['target'] = df_income_test['target'].str.strip()
# Transformando el atributo Target del dataset test
df_income_test['target'] = label_encoder.fit_transform(df_income_test['target'])
df_income_test.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country  target
# 0             0              40   United-States       0
# 1             0              50   United-States       0
# 2             0              40   United-States       1
# 3             0              40   United-States       1
# 4             0              30   United-States       0

# %%
# Valores que contiene cada atributo
for feature in adults_name:
    print('feature values: ', feature, df_income[feature].unique())
# Out:
# feature values:  age [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# feature values:  workclass [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# feature values:  fnlwgt [ 77516  83311 215646 ...  34066  84661 257302]
# feature values:  education [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# feature values:  education-num [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# feature values:  marital-status [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# feature values:  occupation [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# feature values:  relationship [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# feature values:  race [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# feature values:  sex [' Male' ' Female']
# feature values:  capital-gain [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
# feature values:  capital-loss [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
# feature values:  hours-per-week [40 13 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
# feature values:  native-country [' United-States' ' Cuba' ' Jamaica' ' India' ' ?' ' Mexico' ' South'
#  ' Puerto-Rico' ' Honduras' ' England' ' Canada' ' Germany' ' Iran'
#  ' Philippines' ' Italy' ' Poland' ' Columbia' ' Cambodia' ' Thailand'
#  ' Ecuador' ' Laos' ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic'
#  ' El-Salvador' ' France' ' Guatemala' ' China' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
# feature values:  target [0 1]

# %%
# Valores que contiene cada atributo del conjunto de prueba
for feature in adults_name:
    print('feature values: ', feature, df_income_test[feature].unique())
# Out:
# feature values:  age [25 38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87]
# feature values:  workclass [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# feature values:  fnlwgt [226802  89814 336951 ... 349230 321403  83891]
# feature values:  education [' 11th' ' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 5th-6th' ' Assoc-voc'
#  ' 9th' ' 12th' ' 1st-4th' ' Preschool']
# feature values:  education-num [ 7  9 12 10  6 15  4 13 14 16  3 11  5  8  2  1]
# feature values:  marital-status [' Never-married' ' Married-civ-spouse' ' Widowed' ' Divorced'
#  ' Separated' ' Married-spouse-absent' ' Married-AF-spouse']
# feature values:  occupation [' Machine-op-inspct' ' Farming-fishing' ' Protective-serv' ' ?'
#  ' Other-service' ' Prof-specialty' ' Craft-repair' ' Adm-clerical'
#  ' Exec-managerial' ' Tech-support' ' Sales' ' Priv-house-serv'
#  ' Transport-moving' ' Handlers-cleaners' ' Armed-Forces']
# feature values:  relationship [' Own-child' ' Husband' ' Not-in-family' ' Unmarried' ' Wife'
#  ' Other-relative']
# feature values:  race [' Black' ' White' ' Asian-Pac-Islander' ' Other' ' Amer-Indian-Eskimo']
# feature values:  sex [' Male' ' Female']
# feature values:  capital-gain [    0  7688  3103  6418  7298  3908 14084  5178 15024 99999  2597  2907
#   4650  6497  1055  5013 27828  4934  4064  3674  2174 10605  3418   114
#   2580  3411  4508  4386  8614 13550  6849  2463  3137  2885  2964  1471
#  10566  2354  1424  1455  3325  4416 25236   594  2105  4787  2829   401
#   4865  1264  1506 10520  3464  2653 20051  4101  1797  2407  3471  1086
#   1848 14344  1151  2993  2290 15020  9386  2202  3818  2176  5455 11678
#   7978  7262  6514 41310  3456  7430  2414  2062 34095  1831  6723  5060
#  15831  2977  2346  3273  2329  9562  2635  4931  1731  6097   914  7896
#   5556  1409  3781  3942  2538  3887 25124  7443  5721  1173  4687  6612
#   6767  2961   991  2036  2936]
# feature values:  capital-loss [   0 1721 1876 2415 1887  625 1977 2057 1429 1590 1485 2051 2377 1672
#  1628 1902 1602 1741 2444 1408 2001 2042 1740 1825 1848 1719 3004 2179
#  1573 2205 1258 2339 1726 2258 1340 1504 2559 1668 1974 1980 1564 2547
#  2002 1669 1617  323 3175 2472 2174 1579 2129 1510 1735 2282 1870 1411
#  1911 1651 1092 1762 2457 2231 2238  653 1138 2246 2603 2392 1944 1380
#  2465 1421 3770 1594  213 2149 2824 1844 2467 2163 1816 1648]
# feature values:  hours-per-week [40 50 30 32 10 39 35 48 25 20 45 47  6 43 90 54 60 38 36 18 24 44 56 28
#  16 41 22 55 14 33 37  8 12 70 15 75 52 84 42 80 68 99 65  5 17 72 53 29
#  96 21 46  3  1 23 49 67 76  7  2 58 26 34  4 51 78 63 31 92 77 27 85 13
#  19 98 62 66 57 11 86 59  9 64 73 61 88 79 89 74 69]
# feature values:  native-country [' United-States' ' ?' ' Peru' ' Guatemala' ' Mexico'
#  ' Dominican-Republic' ' Ireland' ' Germany' ' Philippines' ' Thailand'
#  ' Haiti' ' El-Salvador' ' Puerto-Rico' ' Vietnam' ' South' ' Columbia'
#  ' Japan' ' India' ' Cambodia' ' Poland' ' Laos' ' England' ' Cuba'
#  ' Taiwan' ' Italy' ' Canada' ' Portugal' ' China' ' Nicaragua'
#  ' Honduras' ' Iran' ' Scotland' ' Jamaica' ' Ecuador' ' Yugoslavia'
#  ' Hungary' ' Hong' ' Greece' ' Trinadad&Tobago'
#  ' Outlying-US(Guam-USVI-etc)' ' France']
# feature values:  target [0 1]

# %%
# Contando los valores nulos en el conjunto de datos
for columna in adults_name:
    conteo = df_income[columna].replace(['?', ' ', ' ?'], np.nan).isnull().sum()
    if conteo > 0:
        porcentaje = (conteo /  df_income[feature].shape[0]) * 100 
        print(f"Cantidad de valores nulos en la columna (Conjunto de datos de Prueba) {columna}: {conteo} = {porcentaje.round(2)}%")
# Out:
# Cantidad de valores nulos en la columna (Conjunto de datos de Prueba) workclass: 1836 = 5.64%
# Cantidad de valores nulos en la columna (Conjunto de datos de Prueba) occupation: 1843 = 5.66%
# Cantidad de valores nulos en la columna (Conjunto de datos de Prueba) native-country: 583 = 1.79%

# %%
# Contando los valores nulos en el conjunto de datos
for columna in adults_name:
    conteo = df_income_test[columna].replace(['?', ' ', ' ?'], np.nan).isnull().sum()
    if conteo > 0:
        porcentaje = (conteo /  df_income_test[feature].shape[0]) * 100 
        print(f"Cantidad de valores nulos en la columna {columna}: {conteo} = {porcentaje.round(2)}%")
# Out:
# Cantidad de valores nulos en la columna workclass: 963 = 5.91%
# Cantidad de valores nulos en la columna occupation: 966 = 5.93%
# Cantidad de valores nulos en la columna native-country: 274 = 1.68%

# %% [markdown]
# ### Histograma de los atributos

# %%
cols = ['workclass', 'education', 'marital-status','occupation', 'relationship', 'race', 'sex', 'native-country']
col_num_att = ['age','fnlwgt','education-num','capital-gain','capital-loss','hours-per-week']

# %%
fig, axs = plt.subplots(2, 3, figsize=(16, 8))

def create_histogram(ax, data, column_name, x_label, y_label):
    ax.hist(data)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# Loop through each subplot and create a histogram
for i, name in enumerate(col_num_att):
    row = int(i / 3)
    col = i % 3
    create_histogram(axs[row, col], df_income[name], name, name, 'Frequency')

#fig.tight_layout()
fig.suptitle('Histogramas de los atributos de Adults Income')
plt.show()
#fig.savefig("./Imagenes/adult-hist.eps", transparent=True, bbox_inches = 'tight')

# %% [markdown]
# El atributo 'age' tiene una distribucion normal con un sesgo a la izquierda, se puede identificar que existen mas registros con personas de la edad entre los 20 a 50 o 60 años, mientras que personas mayores a 60 años no tienen tantos registros.
#
# Continuando con 'fnlwgt', de igual manera tiene una distribucion normal sesgada a la izquierda con el valor 0.25 que tiene la mayor frecuencia.
#
# El atributo 'education-num', la frecuencia mas alta es con el valor de 10.0, seguida del valor 13.0 y 14.0, mientras que para los valores 2.5 a 1.5 y 15.0, tienen una frecuencia muy baja.
#
# Los atributos 'capital gain' y 'capital loss' son muy parecidos, ambos tienen la frecuencia mas alta con el valor de 0, mientras que para los demas valores de estos atributos no superan las 5,000 registros.
#
# Por ultimo el atributo 'hours-per-week' la mayoria de las frecuencias estan en el valor 40, mientras que los demas valores tienen frecuencias bajas.

# %%
sns.boxplot(x='age', data=df_income)
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# Existen outliear a partir de los 80 años, por lo que tomara la decision de eliminar esos registros para reducir el conjunto de datos

# %%
# Graficando el atributo target
sns.countplot(x='target', data=df_income, hue='target')
plt.title(f'Distribución de target')
plt.legend(['<=50k', '>50k'], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#one hot encoding
# o binaria
plt.show()

# %% [markdown]
# Existen un desbalance en el atributo 'target' lo que podria dificultar la clasificacion para el modelo de prediccion, especialmente cuando se trata de predecir la clase minoritaria.

# %% [markdown]
# ### Correlacion de los atributos numericos

# %%
# Calcular la matriz de correlación
#correlation_matrix = df_income.corr(col_num_att)
numeric_cols = df_income.select_dtypes(include=['number'])
numeric_cols.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
# target          0.234037 -0.009463       0.335154      0.223329      0.150526
#
#                 hours-per-week    target
# age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# education-num         0.148123  0.335154
# capital-gain          0.078409  0.223329
# capital-loss          0.054256  0.150526
# hours-per-week        1.000000  0.229689
# target                0.229689  1.000000

# %% [markdown]
# El atributo 'fnlwgt' tiene una correlacion de -0.009463 con respecto al atributo 'target' por lo que no representa una atributo que aporte una informacion util para el proceso del aprendizaje de los modelos.
#
# Un atributo con una correlación tan baja como 'fnlwgt' puede introducir ruido en el modelo de aprendizaje reduciendo la precisión de las predicciones.
# Se tomara la decicsion de eliminar el atributo 'fnlwgt' porque contiene una correlacion practimaente nula con el atributo 'target' y ademas tiene correlacion baja tambien con los demas atributos.
#
# Los atributos 'age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week', si bien no tienen una alta correlacion con respecto al atributo 'target', pueden aportar informacion que sea de ayuda para el modelo de aprendizaje.

# %% [markdown]
# ### Grafico de barras de los atributos categoricos

# %% [markdown]
# #### Atributo Workclass

# %%
sns.countplot(x='target', hue=cols[0], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[0]}')
plt.legend(title=cols[0], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#one hot encoding
# o binaria
plt.show()

# %% [markdown]
# El atributo 'workclass' con el valor 'Private' tiene la mayor frecuencia en ambas clases del atributo 'target', mientras que por el otro lado, los demas valores categoricos tienen la misma frecuencia en ambas clases, siendo algo menores en la clase de '>50k' esto porque esa clase no contiene tantos registros en comparacion con la clase '<=50k' (este atributo se puede convertir a un atributo binario o utilizando one hot encoding)

# %% [markdown]
# #### Atributo Education

# %%
sns.countplot(x='target', hue=cols[1], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[1]}')
plt.legend(title=cols[1], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
# ordinal encoding
plt.show()

# %% [markdown]
# Este atributo resulta redundante porque tenemos el atributo 'education-num' que representa la misma informacion que el atributo 'education', por lo que se eliminara el atributo 'education' debido a que el atributo 'education-num' ya esta en un formato numerico.

# %% [markdown]
# #### Atributo Marital-status

# %%
sns.countplot(x='target', hue=cols[2], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[2]}')
plt.legend(title=cols[2], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#one hot encodign
plt.show()

# %% [markdown]
# El atributo 'marital status' contiene el estado de la persona, contiene valores categoricos sobre el estado civil de la persona, observando los valores de este atributo, podemos agruparlos en dos categorias, 'married' y 'not-married', reduciendo la cantidad de los valores para dicho atributo. Una alternativa es utilizar la tecnica one-hot encoding para crear mas atributos que representen cada categoria, esto agregaria mas dimensionalidad al conjunto de datos pero puede ser una opcion interesante para observar si aporta algo de informacion util para el modelo de aprendizaje.

# %% [markdown]
# #### Atributo Occupation

# %%
sns.countplot(x='target', hue=cols[3], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[3]}')
plt.legend(title=cols[3], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#one hot encoding
plt.show()

# %% [markdown]
# El atributo 'occupation' contiene valore categoricos, en este caso no se podra realizar un agrupamiento porque perderiamos informacion, en su caso se utilizar una tecnica para generar nuevas columnas con valores binarios.

# %% [markdown]
# #### Atributo Relationship

# %%
sns.countplot(x='target', hue=cols[4], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[4]}')
plt.legend(title=cols[4], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#one hot encoding
# se puede unir por marital status
plt.show()

# %% [markdown]
# Este atributo es parecido al atributo 'marital-status', sera evaluado si incluirlo en el conjunto de entrenamiento o eliminarlo.

# %% [markdown]
# #### Atributo Race

# %%
sns.countplot(x='target', hue=cols[5], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[5]}')
plt.legend(title=cols[5], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#One hot encoding
plt.show()

# %% [markdown]
# Este atributo especifica la raza de las personas, en este caso no hay mucha informacion que sacar debido a que para la priemera clase como para la segunda se tiene la mismas frecuencias de los valores, se evaluara la opcion si eliminar este atributo del conjunto de datos de entrenamiento.

# %% [markdown]
# #### Atributo Sex

# %%
sns.countplot(x='target', hue=cols[6], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[6]}')
plt.legend(title=cols[6], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
plt.show()

# %% [markdown]
# El atributo 'sex' se puede representar en un valor binario 0 y 1, siendo 0 representando al valor 'Male' y le 1 al valor 'Female'.

# %% [markdown]
# #### Atributo Native-country

# %%
sns.countplot(x='target', hue=cols[7], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[7]}')
plt.legend(title=cols[7], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#Codificacion binaria
plt.show()

# %% [markdown]
# Este atributo contiene muchos valores, de los cuales todos a excepcion del valor 'United-States' tienen una frecuencia muy inferior en comparacion con 'United-States', por lo que una opcion es agrupar los demas paises como 'Not USA' para representarlos en un unico valor, ademas ayudaria a disminuir los valores del atributo 'naive-country'

# %% [markdown]
# ## Preprocesamiento de los datos

# %% [markdown]
# ### Limpieza

# %% [markdown]
# #### Eliminacion de columnas

# %%
# Eliminar las columnas seleccionadas y explicadas anteriormente
delete_cols = ['education', 'race', 'fnlwgt']

# %%
# Eliminar una sola columna
df_income = df_income.drop(delete_cols, axis=1)
df_income
# Out:
#        age          workclass  education-num       marital-status  \
# 0       39          State-gov             13        Never-married
# 1       50   Self-emp-not-inc             13   Married-civ-spouse
# 2       38            Private              9             Divorced
# 3       53            Private              7   Married-civ-spouse
# 4       28            Private             13   Married-civ-spouse
# ...    ...                ...            ...                  ...
# 32556   27            Private             12   Married-civ-spouse
# 32557   40            Private              9   Married-civ-spouse
# 32558   58            Private              9              Widowed
# 32559   22            Private              9        Never-married
# 32560   52       Self-emp-inc              9   Married-civ-spouse
#
#                occupation    relationship      sex  capital-gain  \
# 0            Adm-clerical   Not-in-family     Male          2174
# 1         Exec-managerial         Husband     Male             0
# 2       Handlers-cleaners   Not-in-family     Male             0
# 3       Handlers-cleaners         Husband     Male             0
# 4          Prof-specialty            Wife   Female             0
# ...                   ...             ...      ...           ...
# 32556        Tech-support            Wife   Female             0
# 32557   Machine-op-inspct         Husband     Male             0
# 32558        Adm-clerical       Unmarried   Female             0
# 32559        Adm-clerical       Own-child     Male             0
# 32560     Exec-managerial            Wife   Female         15024
#
#        capital-loss  hours-per-week  native-country  target
# 0                 0              40   United-States       0
# 1                 0              13   United-States       0
# 2                 0              40   United-States       0
# 3                 0              40   United-States       0
# 4                 0              40            Cuba       0
# ...             ...             ...             ...     ...
# 32556             0              38   United-States       0
# 32557             0              40   United-States       1
# 32558             0              40   United-States       0
# 32559             0              20   United-States       0
# 32560             0              40   United-States       1
#
# [32561 rows x 12 columns]

# %%
# Eliminar una sola columna del conjunto de datos de Prueba
df_income_test = df_income_test.drop(delete_cols, axis=1)
df_income_test
# Out:
#        age      workclass  education-num       marital-status  \
# 0       25        Private              7        Never-married
# 1       38        Private              9   Married-civ-spouse
# 2       28      Local-gov             12   Married-civ-spouse
# 3       44        Private             10   Married-civ-spouse
# 4       18              ?             10        Never-married
# ...    ...            ...            ...                  ...
# 16276   39        Private             13             Divorced
# 16277   64              ?              9              Widowed
# 16278   38        Private             13   Married-civ-spouse
# 16279   44        Private             13             Divorced
# 16280   35   Self-emp-inc             13   Married-civ-spouse
#
#                occupation     relationship      sex  capital-gain  \
# 0       Machine-op-inspct        Own-child     Male             0
# 1         Farming-fishing          Husband     Male             0
# 2         Protective-serv          Husband     Male             0
# 3       Machine-op-inspct          Husband     Male          7688
# 4                       ?        Own-child   Female             0
# ...                   ...              ...      ...           ...
# 16276      Prof-specialty    Not-in-family   Female             0
# 16277                   ?   Other-relative     Male             0
# 16278      Prof-specialty          Husband     Male             0
# 16279        Adm-clerical        Own-child     Male          5455
# 16280     Exec-managerial          Husband     Male             0
#
#        capital-loss  hours-per-week  native-country  target
# 0                 0              40   United-States       0
# 1                 0              50   United-States       0
# 2                 0              40   United-States       1
# 3                 0              40   United-States       1
# 4                 0              30   United-States       0
# ...             ...             ...             ...     ...
# 16276             0              36   United-States       0
# 16277             0              40   United-States       0
# 16278             0              50   United-States       0
# 16279             0              40   United-States       0
# 16280             0              60   United-States       1
#
# [16281 rows x 12 columns]

# %% [markdown]
# #### Eliminacion de registros outliers de age

# %%
df_income = df_income.drop(df_income[df_income['age'] >= 70].index)

# %%
df_income_test = df_income_test.drop(df_income_test[df_income_test['age'] >= 70].index)

# %%
# Comprobacion de como quedo el atributo age despues de la limpieza
sns.boxplot(x='age', data=df_income)
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### Transformacion

# %% [markdown]
# #### Rellenado de valores faltantes

# %%
#conteo = df_income[columna].replace(['?', ' ', ' ?'], np.nan).isnull().sum()
#Transformando los valores que representan nulo a verdaderos valores nulos
# Contando los valores nulos en el conjunto de datos
for columna in df_income.columns:
    df_income[columna] = df_income[columna].replace(['?', ' ', ' ?'], np.nan)
print(df_income.isnull().sum())
# Out:
# age                  0
# workclass         1662
# education-num        0
# marital-status       0
# occupation        1669
# relationship         0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     575
# target               0
# dtype: int64

# %%
# Contando los valores nulos en el conjunto de datos de prueba
for columna in df_income_test.columns:
    df_income_test[columna] = df_income_test[columna].replace(['?', ' ', ' ?'], np.nan)
print(df_income_test.isnull().sum())
# Out:
# age                 0
# workclass         877
# education-num       0
# marital-status      0
# occupation        880
# relationship        0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    272
# target              0
# dtype: int64

# %%
# Para la limpieza de los datos vamos a rellenar los valores nulos que existen en los atributos con el valor mas frecuente de cada atributo
mode_work = df_income['workclass'].mode()
mode_occu = df_income['occupation'].mode()
mode_native = df_income['native-country'].mode()
#moda = df['fruta'].mode()
print('moda de workclass ->      ', mode_work[0])
print('moda de occupation ->     ', mode_occu[0])
print('moda de native-country -> ', mode_native[0])
# Out:
# moda de workclass ->        Private
# moda de occupation ->       Prof-specialty
# moda de native-country ->   United-States

# %%
# Rellenando los valores con la moda en los atributos con valores nulos
df_income['workclass'] = df_income['workclass'].fillna(mode_work[0])
df_income['occupation'] = df_income['occupation'].fillna(mode_occu[0])
df_income['native-country']= df_income['native-country'].fillna(mode_native[0])

# %%
# Comprobacion de que no existe valores nulos
print(df_income.isnull().sum())
# Out:
# age               0
# workclass         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# target            0
# dtype: int64

# %%
# Rellenado de valores faltantes para el conjunto de datos de Prueba
mode_work = df_income_test['workclass'].mode()
mode_occu = df_income_test['occupation'].mode()
mode_native = df_income_test['native-country'].mode()

print('moda de workclass ->      ', mode_work[0])
print('moda de occupation ->     ', mode_occu[0])
print('moda de native-country -> ', mode_native[0])

# Rellenando los valores con la moda en los atributos con valores nulos
df_income_test['workclass'] = df_income_test['workclass'].fillna(mode_work[0])
df_income_test['occupation'] = df_income_test['occupation'].fillna(mode_occu[0])
df_income_test['native-country']= df_income_test['native-country'].fillna(mode_native[0])

# Comprobacion de que no existe valores nulos
print(df_income_test.isnull().sum())
# Out:
# moda de workclass ->        Private
# moda de occupation ->       Craft-repair
# moda de native-country ->   United-States
# age               0
# workclass         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# target            0
# dtype: int64

# %% [markdown]
# #### Reduccion de los datos

# %%
# Atributo capital-loss
# Se puede reducir a dos valores (=0 y >0 ) del rango [0, 1]
df_income['capital-loss'].value_counts()

df_income['capital-loss'] = np.where(df_income['capital-loss'] > 0, '>0', '0')
df_income['capital-loss'].unique()

# Atributo capital-gain
# Se puede reducir a dos valores (=0 y >0 ) del rango [0, 1]
df_income['capital-gain'].value_counts()

df_income['capital-gain'] = np.where(df_income['capital-gain'] > 0, '>0', '0')
df_income['capital-gain'].unique()
# Out:
# array(['>0', '0'], dtype=object)

# %%
# Reduccion de datos para el conjunto de datos de prueba
# Atributo capital-loss
df_income_test['capital-loss'].value_counts()

df_income_test['capital-loss'] = np.where(df_income_test['capital-loss'] > 0, '>0', '0')
df_income_test['capital-loss'].unique()

# Atributo capital-gain
df_income_test['capital-gain'].value_counts()

df_income_test['capital-gain'] = np.where(df_income_test['capital-gain'] > 0, '>0', '0')
df_income_test['capital-gain'].unique()
# Out:
# array(['0', '>0'], dtype=object)

# %%
sns.countplot(x='target', hue=col_num_att[4], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {col_num_att[4]}')
plt.legend(title=col_num_att[4], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()  # Uncomment for better layout control
#plt.savefig("./Imagenes/adult-cap-loss.eps", transparent=True, bbox_inches='tight')
plt.show()  # Show the plot for visual inspection

# %%
sns.countplot(x='target', hue=col_num_att[3], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {col_num_att[3]}')
plt.legend(title=col_num_att[3], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#plt.savefig("./Imagenes/adult-cap-gain.eps", transparent=True, bbox_inches = 'tight') 
plt.show()

# %%
# Atributo marital-status
df_income['marital-status'] = df_income['marital-status'].replace([' Married-civ-spouse', ' Married-AF-spouse'], 'married')
df_income['marital-status'] = df_income['marital-status'].replace([' Never-married', ' Divorced', ' Married-spouse-absent', ' Separated', ' Widowed'], 'not-married')
# Atributo education
df_income['marital-status'].unique()
# Out:
# array(['not-married', 'married'], dtype=object)

# %%
# Atributo marital-status
df_income_test['marital-status'] = df_income_test['marital-status'].replace([' Married-civ-spouse', ' Married-AF-spouse'], 'married')
df_income_test['marital-status'] = df_income_test['marital-status'].replace([' Never-married', ' Divorced', ' Married-spouse-absent', ' Separated', ' Widowed'], 'not-married')
# Atributo education
df_income_test['marital-status'].unique()
# Out:
# array(['not-married', 'married'], dtype=object)

# %%
sns.countplot(x='target', hue=cols[2], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[2]}')
plt.legend(title=cols[2], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#plt.savefig("./Imagenes/adult-marital.eps", transparent=True, bbox_inches = 'tight') 
plt.show()

# %%
df_income['native-country'] = df_income['native-country'].replace([' United-States', ' Outlying-US(Guam-USVI-etc)'], 'US')
#df_income['native-country'] = df_income['native-country'].replace(df_income['native-country'].unique(), 'Not-US')

# %%
df_income_test['native-country'] = df_income_test['native-country'].replace([' United-States', ' Outlying-US(Guam-USVI-etc)'], 'US')

# %%
df_temp = df_income.copy()

# %%
df_income = df_temp

# %%
paises_restantes = [pais for pais in df_income['native-country'].unique() if pais not in 'US']
paises_restantes
# Out:
# [' Cuba',
#  ' Jamaica',
#  ' India',
#  ' Mexico',
#  ' South',
#  ' Puerto-Rico',
#  ' Honduras',
#  ' England',
#  ' Canada',
#  ' Germany',
#  ' Iran',
#  ' Philippines',
#  ' Italy',
#  ' Poland',
#  ' Cambodia',
#  ' Thailand',
#  ' Ecuador',
#  ' Laos',
#  ' Taiwan',
#  ' Haiti',
#  ' Portugal',
#  ' Dominican-Republic',
#  ' El-Salvador',
#  ' France',
#  ' Guatemala',
#  ' China',
#  ' Japan',
#  ' Yugoslavia',
#  ' Peru',
#  ' Scotland',
#  ' Trinadad&Tobago',
#  ' Greece',
#  ' Nicaragua',
#  ' Vietnam',
#  ' Hong',
#  ' Columbia',
#  ' Ireland',
#  ' Hungary',
#  ' Holand-Netherlands']

# %%
df_income['native-country'] = df_income['native-country'].replace(paises_restantes, 'Not-US')

# %%
df_income_test['native-country'] = df_income_test['native-country'].replace(paises_restantes, 'Not-US')

# %%
sns.countplot(x='target', hue=cols[7], data=df_income, palette='coolwarm')
plt.title(f'Distribución de target por {cols[7]}')
plt.legend(title=cols[7], bbox_to_anchor=(1.05, 1), loc='upper left')

#plt.tight_layout()
#Codificacion binaria
plt.show()

# %%
# Transformando el atributo Native-country
df_income['native-country'] = label_encoder.fit_transform(df_income['native-country'])

# %%
# Transformando el atributo Marital Status
df_income['marital-status'] = label_encoder.fit_transform(df_income['marital-status'])

# %%
# Transformando el atributo Sex
df_income['sex'] = label_encoder.fit_transform(df_income['sex'])

# %%
# Transformando el atributo Capital loss & gain
df_income['capital-loss'] = label_encoder.fit_transform(df_income['capital-loss'])
df_income['capital-gain'] = label_encoder.fit_transform(df_income['capital-gain'])

# %%
df_income
# Out:
#        age          workclass  education-num  marital-status  \
# 0       39          State-gov             13               1
# 1       50   Self-emp-not-inc             13               0
# 2       38            Private              9               1
# 3       53            Private              7               0
# 4       28            Private             13               0
# ...    ...                ...            ...             ...
# 32556   27            Private             12               0
# 32557   40            Private              9               0
# 32558   58            Private              9               1
# 32559   22            Private              9               1
# 32560   52       Self-emp-inc              9               0
#
#                occupation    relationship  sex  capital-gain  capital-loss  \
# 0            Adm-clerical   Not-in-family    1             1             0
# 1         Exec-managerial         Husband    1             0             0
# 2       Handlers-cleaners   Not-in-family    1             0             0
# 3       Handlers-cleaners         Husband    1             0             0
# 4          Prof-specialty            Wife    0             0             0
# ...                   ...             ...  ...           ...           ...
# 32556        Tech-support            Wife    0             0             0
# 32557   Machine-op-inspct         Husband    1             0             0
# 32558        Adm-clerical       Unmarried    0             0             0
# 32559        Adm-clerical       Own-child    1             0             0
# 32560     Exec-managerial            Wife    0             1             0
#
#        hours-per-week  native-country  target
# 0                  40               1       0
# 1                  13               1       0
# 2                  40               1       0
# 3                  40               1       0
# 4                  40               0       0
# ...               ...             ...     ...
# 32556              38               1       0
# 32557              40               1       1
# 32558              40               1       0
# 32559              20               1       0
# 32560              40               1       1
#
# [31932 rows x 12 columns]

# %%
# Transformando el atributo Native-country
df_income_test['native-country'] = label_encoder.fit_transform(df_income_test['native-country'])

# Transformando el atributo Marital Status
df_income_test['marital-status'] = label_encoder.fit_transform(df_income_test['marital-status'])

# Transformando el atributo Sex
df_income_test['sex'] = label_encoder.fit_transform(df_income_test['sex'])

# Transformando el atributo Capital loss & gain
df_income_test['capital-loss'] = label_encoder.fit_transform(df_income_test['capital-loss'])
df_income_test['capital-gain'] = label_encoder.fit_transform(df_income_test['capital-gain'])

df_income_test
# Out:
#        age      workclass  education-num  marital-status          occupation  \
# 0       25        Private              7               1   Machine-op-inspct
# 1       38        Private              9               0     Farming-fishing
# 2       28      Local-gov             12               0     Protective-serv
# 3       44        Private             10               0   Machine-op-inspct
# 4       18        Private             10               1        Craft-repair
# ...    ...            ...            ...             ...                 ...
# 16276   39        Private             13               1      Prof-specialty
# 16277   64        Private              9               1        Craft-repair
# 16278   38        Private             13               0      Prof-specialty
# 16279   44        Private             13               1        Adm-clerical
# 16280   35   Self-emp-inc             13               0     Exec-managerial
#
#           relationship  sex  capital-gain  capital-loss  hours-per-week  \
# 0            Own-child    1             0             0              40
# 1              Husband    1             0             0              50
# 2              Husband    1             0             0              40
# 3              Husband    1             1             0              40
# 4            Own-child    0             0             0              30
# ...                ...  ...           ...           ...             ...
# 16276    Not-in-family    0             0             0              36
# 16277   Other-relative    1             0             0              40
# 16278          Husband    1             0             0              50
# 16279        Own-child    1             1             0              40
# 16280          Husband    1             0             0              60
#
#        native-country  target
# 0                   1       0
# 1                   1       0
# 2                   1       1
# 3                   1       1
# 4                   1       0
# ...               ...     ...
# 16276               1       0
# 16277               1       0
# 16278               1       0
# 16279               1       0
# 16280               1       1
#
# [15909 rows x 12 columns]

# %% [markdown]
# #### Generacion de nuevos atributos

# %%
df_temp = df_income.copy()

# %%
df_income = pd.get_dummies(df_income, columns=['occupation', 'relationship', 'workclass'], prefix=['o_', 'r_', 'w_'], drop_first=True)

# %%
df_income
# Out:
#        age  education-num  marital-status  sex  capital-gain  capital-loss  \
# 0       39             13               1    1             1             0
# 1       50             13               0    1             0             0
# 2       38              9               1    1             0             0
# 3       53              7               0    1             0             0
# 4       28             13               0    0             0             0
# ...    ...            ...             ...  ...           ...           ...
# 32556   27             12               0    0             0             0
# 32557   40              9               0    1             0             0
# 32558   58              9               1    0             0             0
# 32559   22              9               1    1             0             0
# 32560   52              9               0    0             1             0
#
#        hours-per-week  native-country  target  o__ Armed-Forces  ...  \
# 0                  40               1       0             False  ...
# 1                  13               1       0             False  ...
# 2                  40               1       0             False  ...
# 3                  40               1       0             False  ...
# 4                  40               0       0             False  ...
# ...               ...             ...     ...               ...  ...
# 32556              38               1       0             False  ...
# 32557              40               1       1             False  ...
# 32558              40               1       0             False  ...
# 32559              20               1       0             False  ...
# 32560              40               1       1             False  ...
#
#        r__ Own-child  r__ Unmarried  r__ Wife  w__ Local-gov  \
# 0              False          False     False          False
# 1              False          False     False          False
# 2              False          False     False          False
# 3              False          False     False          False
# 4              False          False      True          False
# ...              ...            ...       ...            ...
# 32556          False          False      True          False
# 32557          False          False     False          False
# 32558          False           True     False          False
# 32559           True          False     False          False
# 32560          False          False      True          False
#
#        w__ Never-worked  w__ Private  w__ Self-emp-inc  w__ Self-emp-not-inc  \
# 0                 False        False             False                 False
# 1                 False        False             False                  True
# 2                 False         True             False                 False
# 3                 False         True             False                 False
# 4                 False         True             False                 False
# ...                 ...          ...               ...                   ...
# 32556             False         True             False                 False
# 32557             False         True             False                 False
# 32558             False         True             False                 False
# 32559             False         True             False                 False
# 32560             False        False              True                 False
#
#        w__ State-gov  w__ Without-pay
# 0               True            False
# 1              False            False
# 2              False            False
# 3              False            False
# 4              False            False
# ...              ...              ...
# 32556          False            False
# 32557          False            False
# 32558          False            False
# 32559          False            False
# 32560          False            False
#
# [31932 rows x 34 columns]

# %% [markdown]
# El conjunto de datos aumento a 34 columnas, se utilizara la tecnica de normalizacion de los datos para que todas las columnas tengan la misma escala y ademas de hacer un PCA al conjunto de datos para reducir los atributos.

# %%
# Generando nuevos atributos para el conjunto de datos de Prueba
df_income_test = pd.get_dummies(df_income_test, columns=['occupation', 'relationship', 'workclass'], prefix=['o_', 'r_', 'w_'], drop_first=True)
df_income_test
# Out:
#        age  education-num  marital-status  sex  capital-gain  capital-loss  \
# 0       25              7               1    1             0             0
# 1       38              9               0    1             0             0
# 2       28             12               0    1             0             0
# 3       44             10               0    1             1             0
# 4       18             10               1    0             0             0
# ...    ...            ...             ...  ...           ...           ...
# 16276   39             13               1    0             0             0
# 16277   64              9               1    1             0             0
# 16278   38             13               0    1             0             0
# 16279   44             13               1    1             1             0
# 16280   35             13               0    1             0             0
#
#        hours-per-week  native-country  target  o__ Armed-Forces  ...  \
# 0                  40               1       0             False  ...
# 1                  50               1       0             False  ...
# 2                  40               1       1             False  ...
# 3                  40               1       1             False  ...
# 4                  30               1       0             False  ...
# ...               ...             ...     ...               ...  ...
# 16276              36               1       0             False  ...
# 16277              40               1       0             False  ...
# 16278              50               1       0             False  ...
# 16279              40               1       0             False  ...
# 16280              60               1       1             False  ...
#
#        r__ Own-child  r__ Unmarried  r__ Wife  w__ Local-gov  \
# 0               True          False     False          False
# 1              False          False     False          False
# 2              False          False     False           True
# 3              False          False     False          False
# 4               True          False     False          False
# ...              ...            ...       ...            ...
# 16276          False          False     False          False
# 16277          False          False     False          False
# 16278          False          False     False          False
# 16279           True          False     False          False
# 16280          False          False     False          False
#
#        w__ Never-worked  w__ Private  w__ Self-emp-inc  w__ Self-emp-not-inc  \
# 0                 False         True             False                 False
# 1                 False         True             False                 False
# 2                 False        False             False                 False
# 3                 False         True             False                 False
# 4                 False         True             False                 False
# ...                 ...          ...               ...                   ...
# 16276             False         True             False                 False
# 16277             False         True             False                 False
# 16278             False         True             False                 False
# 16279             False         True             False                 False
# 16280             False        False              True                 False
#
#        w__ State-gov  w__ Without-pay
# 0              False            False
# 1              False            False
# 2              False            False
# 3              False            False
# 4              False            False
# ...              ...              ...
# 16276          False            False
# 16277          False            False
# 16278          False            False
# 16279          False            False
# 16280          False            False
#
# [15909 rows x 34 columns]

# %% [markdown]
# #### Normalizacion de los datos

# %%
# Crear un objeto StandardScaler
scaler = StandardScaler()

# Ajustar el scaler a los datos y transformar
df_income_scaled = scaler.fit_transform(df_income)

# %%
df_income_scaled = pd.DataFrame(df_income_scaled, columns=df_income.columns)

# %%
df_income_scaled
# Out:
#             age  education-num  marital-status       sex  capital-gain  \
# 0      0.090142       1.138375        0.921695  0.703025      3.347599
# 1      0.955164       1.138375       -1.084957  0.703025     -0.298722
# 2      0.011503      -0.428799        0.921695  0.703025     -0.298722
# 3      1.191080      -1.212386       -1.084957  0.703025     -0.298722
# 4     -0.774881       1.138375       -1.084957 -1.422424     -0.298722
# ...         ...            ...             ...       ...           ...
# 31927 -0.853520       0.746582       -1.084957 -1.422424     -0.298722
# 31928  0.168780      -0.428799       -1.084957  0.703025     -0.298722
# 31929  1.584272      -0.428799        0.921695 -1.422424     -0.298722
# 31930 -1.246712      -0.428799        0.921695  0.703025     -0.298722
# 31931  1.112441      -0.428799       -1.084957 -1.422424      3.347599
#
#        capital-loss  hours-per-week  native-country    target  \
# 0         -0.220847       -0.057836        0.306918 -0.565054
# 1         -0.220847       -2.288381        0.306918 -0.565054
# 2         -0.220847       -0.057836        0.306918 -0.565054
# 3         -0.220847       -0.057836        0.306918 -0.565054
# 4         -0.220847       -0.057836       -3.258199 -0.565054
# ...             ...             ...             ...       ...
# 31927     -0.220847       -0.223061        0.306918 -0.565054
# 31928     -0.220847       -0.057836        0.306918  1.769742
# 31929     -0.220847       -0.057836        0.306918 -0.565054
# 31930     -0.220847       -1.710091        0.306918 -0.565054
# 31931     -0.220847       -0.057836        0.306918  1.769742
#
#        o__ Armed-Forces  ...  r__ Own-child  r__ Unmarried  r__ Wife  \
# 0             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 1             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 2             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 3             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 4             -0.016791  ...      -0.433987      -0.344918  4.421342
# ...                 ...  ...            ...            ...       ...
# 31927         -0.016791  ...      -0.433987      -0.344918  4.421342
# 31928         -0.016791  ...      -0.433987      -0.344918 -0.226176
# 31929         -0.016791  ...      -0.433987       2.899241 -0.226176
# 31930         -0.016791  ...       2.304219      -0.344918 -0.226176
# 31931         -0.016791  ...      -0.433987      -0.344918  4.421342
#
#        w__ Local-gov  w__ Never-worked  w__ Private  w__ Self-emp-inc  \
# 0           -0.26274         -0.014808    -1.756103         -0.186200
# 1           -0.26274         -0.014808    -1.756103         -0.186200
# 2           -0.26274         -0.014808     0.569443         -0.186200
# 3           -0.26274         -0.014808     0.569443         -0.186200
# 4           -0.26274         -0.014808     0.569443         -0.186200
# ...              ...               ...          ...               ...
# 31927       -0.26274         -0.014808     0.569443         -0.186200
# 31928       -0.26274         -0.014808     0.569443         -0.186200
# 31929       -0.26274         -0.014808     0.569443         -0.186200
# 31930       -0.26274         -0.014808     0.569443         -0.186200
# 31931       -0.26274         -0.014808    -1.756103          5.370567
#
#        w__ Self-emp-not-inc  w__ State-gov  w__ Without-pay
# 0                 -0.287125       4.879671        -0.020181
# 1                  3.482806      -0.204932        -0.020181
# 2                 -0.287125      -0.204932        -0.020181
# 3                 -0.287125      -0.204932        -0.020181
# 4                 -0.287125      -0.204932        -0.020181
# ...                     ...            ...              ...
# 31927             -0.287125      -0.204932        -0.020181
# 31928             -0.287125      -0.204932        -0.020181
# 31929             -0.287125      -0.204932        -0.020181
# 31930             -0.287125      -0.204932        -0.020181
# 31931             -0.287125      -0.204932        -0.020181
#
# [31932 rows x 34 columns]

# %%
# Ajustar el scaler a los datos y transformar para el conjunto de datos de Prueba
df_income_test_scaled = scaler.transform(df_income_test)

df_income_test_scaled = pd.DataFrame(df_income_test_scaled, columns=df_income_test.columns)
df_income_test_scaled
# Out:
#             age  education-num  marital-status       sex  capital-gain  \
# 0     -1.010796      -1.212386        0.921695  0.703025     -0.298722
# 1      0.011503      -0.428799       -1.084957  0.703025     -0.298722
# 2     -0.774881       0.746582       -1.084957  0.703025     -0.298722
# 3      0.483334      -0.037005       -1.084957  0.703025      3.347599
# 4     -1.561265      -0.037005        0.921695 -1.422424     -0.298722
# ...         ...            ...             ...       ...           ...
# 15904  0.090142       1.138375        0.921695 -1.422424     -0.298722
# 15905  2.056102      -0.428799        0.921695  0.703025     -0.298722
# 15906  0.011503       1.138375       -1.084957  0.703025     -0.298722
# 15907  0.483334       1.138375        0.921695  0.703025      3.347599
# 15908 -0.224412       1.138375       -1.084957  0.703025     -0.298722
#
#        capital-loss  hours-per-week  native-country    target  \
# 0         -0.220847       -0.057836        0.306918 -0.565054
# 1         -0.220847        0.768292        0.306918 -0.565054
# 2         -0.220847       -0.057836        0.306918  1.769742
# 3         -0.220847       -0.057836        0.306918  1.769742
# 4         -0.220847       -0.883964        0.306918 -0.565054
# ...             ...             ...             ...       ...
# 15904     -0.220847       -0.388287        0.306918 -0.565054
# 15905     -0.220847       -0.057836        0.306918 -0.565054
# 15906     -0.220847        0.768292        0.306918 -0.565054
# 15907     -0.220847       -0.057836        0.306918 -0.565054
# 15908     -0.220847        1.594420        0.306918  1.769742
#
#        o__ Armed-Forces  ...  r__ Own-child  r__ Unmarried  r__ Wife  \
# 0             -0.016791  ...       2.304219      -0.344918 -0.226176
# 1             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 2             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 3             -0.016791  ...      -0.433987      -0.344918 -0.226176
# 4             -0.016791  ...       2.304219      -0.344918 -0.226176
# ...                 ...  ...            ...            ...       ...
# 15904         -0.016791  ...      -0.433987      -0.344918 -0.226176
# 15905         -0.016791  ...      -0.433987      -0.344918 -0.226176
# 15906         -0.016791  ...      -0.433987      -0.344918 -0.226176
# 15907         -0.016791  ...       2.304219      -0.344918 -0.226176
# 15908         -0.016791  ...      -0.433987      -0.344918 -0.226176
#
#        w__ Local-gov  w__ Never-worked  w__ Private  w__ Self-emp-inc  \
# 0          -0.262740         -0.014808     0.569443         -0.186200
# 1          -0.262740         -0.014808     0.569443         -0.186200
# 2           3.806039         -0.014808    -1.756103         -0.186200
# 3          -0.262740         -0.014808     0.569443         -0.186200
# 4          -0.262740         -0.014808     0.569443         -0.186200
# ...              ...               ...          ...               ...
# 15904      -0.262740         -0.014808     0.569443         -0.186200
# 15905      -0.262740         -0.014808     0.569443         -0.186200
# 15906      -0.262740         -0.014808     0.569443         -0.186200
# 15907      -0.262740         -0.014808     0.569443         -0.186200
# 15908      -0.262740         -0.014808    -1.756103          5.370567
#
#        w__ Self-emp-not-inc  w__ State-gov  w__ Without-pay
# 0                 -0.287125      -0.204932        -0.020181
# 1                 -0.287125      -0.204932        -0.020181
# 2                 -0.287125      -0.204932        -0.020181
# 3                 -0.287125      -0.204932        -0.020181
# 4                 -0.287125      -0.204932        -0.020181
# ...                     ...            ...              ...
# 15904             -0.287125      -0.204932        -0.020181
# 15905             -0.287125      -0.204932        -0.020181
# 15906             -0.287125      -0.204932        -0.020181
# 15907             -0.287125      -0.204932        -0.020181
# 15908             -0.287125      -0.204932        -0.020181
#
# [15909 rows x 34 columns]

# %% [markdown]
# #### Reduccion de dimensionalidad con PCA

# %%
df_temp = df_income.copy()

# %%
# Crear un objeto PCA y especificar el número de componentes
pca = PCA(n_components=0.85)  # Queremos reducir a una sola dimensión

# Ajustar el PCA a los datos y transformar
df_income_pca = pca.fit_transform(df_income_scaled)

# Crear un DataFrame con los componentes principales
df_income_pca = pd.DataFrame(data = df_income_pca, columns = ['PC' + str(i+1) for i in range(df_income_pca.shape[1])])

# %%
df_income_pca
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -0.965194 -2.461538 -0.999170  1.638883 -0.012445 -0.550691  0.048277
# 1     -2.010235 -0.583064 -1.564256 -0.462168  0.062850  1.835712  0.366935
# 2      1.404573  0.830863 -0.260997  1.769054 -0.229199 -0.968585 -0.161798
# 3      0.088887  2.129559 -0.169476 -0.265115  0.438840 -0.916818 -0.444979
# 4     -0.091995 -1.191615  2.388757 -3.036106  0.627776 -0.085924  2.392148
# ...         ...       ...       ...       ...       ...       ...       ...
# 31927  0.121514 -0.788258  2.362585 -2.307769  0.535232  0.358884  1.166238
# 31928 -0.881629  1.843032  1.044007 -0.697057 -0.202884 -0.911007 -0.188942
# 31929  1.131248 -0.787321  0.211130 -1.354795 -2.065229  0.071411 -0.764691
# 31930  2.238385  0.573219 -0.049798  0.374514  2.154106  0.491172 -0.130993
# 31931 -3.874575 -1.529598  1.906873 -2.623466 -0.308428  3.084455 -2.271209
#
#             PC8       PC9      PC10  ...      PC15      PC16      PC17  \
# 0      1.037606 -1.532629  0.438425  ... -1.094361  0.612374  0.029113
# 1      0.268646 -1.625010  0.096149  ...  0.203148  0.040519 -0.145090
# 2      1.310707  0.142251  0.676678  ...  1.579726  1.150572  0.264154
# 3      0.798028  0.155412  1.107905  ...  1.475205  1.144960  0.281259
# 4      1.670022  0.651484 -0.605123  ... -0.241812  0.299267 -0.305142
# ...         ...       ...       ...  ...       ...       ...       ...
# 31927 -0.500608 -1.155323 -1.477309  ...  3.577993  0.126555  0.191371
# 31928  0.008385  0.688306  0.827398  ... -1.326924 -0.642528 -0.007130
# 31929 -1.646545  0.131780  1.334480  ...  0.324323  0.088349  0.212222
# 31930 -0.275976 -0.428450  0.254824  ... -0.125245  0.115320 -0.061547
# 31931  1.659229 -0.693654 -1.067962  ... -0.535705  1.487501  0.701899
#
#            PC18      PC19      PC20      PC21      PC22      PC23      PC24
# 0     -0.952970  0.883758  0.109869 -0.946612 -0.810787  1.017939 -0.193981
# 1      0.215426  0.912894  0.701273 -0.731371  0.904574  1.588300 -1.629475
# 2     -1.120993  3.062854 -1.529557  0.544768 -0.984611  0.562766  0.133422
# 3     -1.181394  3.190902 -1.560147  0.542083 -1.163786  0.703665  0.444385
# 4     -0.213043  0.351165 -0.036503  0.749245  0.420417 -3.132510 -1.375841
# ...         ...       ...       ...       ...       ...       ...       ...
# 31927  1.750803  0.037625 -0.980780  2.282761  1.450054 -1.277337  0.180638
# 31928  0.231234 -0.086932  0.352400  0.273563  0.137608  1.303916  0.063675
# 31929 -0.111587  0.414779 -0.197526 -0.235174 -0.165819 -0.128662  0.398081
# 31930  0.141334 -0.341969  0.585251  0.196950  0.110906  0.351029 -0.138000
# 31931  0.194108  0.584216 -0.505396  2.844392  1.038737  0.131713  0.996005
#
# [31932 rows x 24 columns]

# %% [markdown]
# Con PCA se redujo el dataset a 24 columnas

# %%
# Ajustar el PCA a los datos y transformar para el conjunto de datos de Prueba
df_income_test_pca = pca.transform(df_income_test_scaled)

# Crear un DataFrame con los componentes principales
df_income_test_pca = pd.DataFrame(data = df_income_test_pca, columns = ['PC' + str(i+1) for i in range(df_income_test_pca.shape[1])])
df_income_test_pca
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      2.147853  1.666548 -0.086825  0.076311  1.088191 -0.186030 -0.478530
# 1     -0.685470  1.752152 -1.730249 -0.172342 -0.279412  1.186319  1.394276
# 2     -2.535785 -1.992615 -2.418738 -0.752230  2.924491 -3.724385 -3.114634
# 3     -1.675202  1.610702  1.712692 -0.629990 -0.258625 -0.752654 -0.214901
# 4      2.409759  0.540428 -0.101821  0.276631  1.644325  0.370960  0.353518
# ...         ...       ...       ...       ...       ...       ...       ...
# 15904  1.018198 -2.104542  1.082141  1.287185 -0.665993 -0.619226  1.699432
# 15905  0.351587  1.856312 -0.776190 -0.528062 -1.108325 -1.214802  0.434112
# 15906 -0.952666 -0.122917  1.005629  0.469602  0.707755 -0.723173  1.260168
# 15907  0.310835  0.053880  0.827625  0.861010  1.415118  0.571921 -0.196636
# 15908 -3.899040 -0.448185  0.244673  1.060091  0.141256  2.335435 -3.237671
#
#             PC8       PC9      PC10  ...      PC15      PC16      PC17  \
# 0     -0.058004  0.553014  1.241802  ... -1.541918 -0.471129 -0.104690
# 1      0.276136  0.446480  1.681607  ...  1.013341 -0.569020 -0.309479
# 2     -0.187553  1.900389 -1.737932  ...  1.775902 -0.608388 -0.430055
# 3      0.313627  0.735308  1.365933  ... -0.772072 -1.080865  0.152700
# 4     -1.001202 -1.271318 -0.700280  ...  0.109465  0.586679  0.121647
# ...         ...       ...       ...  ...       ...       ...       ...
# 15904  0.088872  0.383457  0.105449  ... -0.314110  0.062197  0.044390
# 15905  1.789660 -0.053380 -0.994330  ...  0.338817 -0.652292  0.686545
# 15906 -0.137379  0.397104  0.890652  ... -0.435359 -0.320009 -0.065828
# 15907 -0.066256 -0.193293  1.085049  ...  0.501311 -0.516452  0.052811
# 15908  1.483573 -0.624956  0.127007  ... -1.342569  0.770305  0.207085
#
#            PC18      PC19      PC20      PC21      PC22      PC23      PC24
# 0      0.477865 -0.404092  0.914838  0.725396  0.634505  1.169001 -0.344828
# 1      0.220008 -0.670621  0.374350 -0.395106 -1.084709 -1.927107  3.186851
# 2      0.648788 -0.699955  0.735470 -1.679450 -0.735220 -1.018020  0.513048
# 3      0.492774 -0.297114  0.523644  0.073289 -0.490897  2.564693 -0.263620
# 4      0.169950 -0.413875  0.843530  0.289632  1.133334 -0.417599 -0.193619
# ...         ...       ...       ...       ...       ...       ...       ...
# 15904 -0.278212  0.065997 -0.055255  0.181250  0.199567 -0.306460  0.416042
# 15905 -0.158038 -0.370371 -0.854170 -1.480204  3.348442  1.265789  1.905265
# 15906 -0.192931 -0.166679  0.032319  0.028886  0.053281 -0.724588  0.633496
# 15907  0.387479 -0.626858  0.692702 -0.148035 -0.584058  1.257374 -0.317929
# 15908  0.174691 -0.623128 -0.501223  2.460849  0.978464 -0.882999  1.058104
#
# [15909 rows x 24 columns]

# %% [markdown]
# ### Integracion

# %% [markdown]
# #### Generando el nuevo conjunto de datos de entrenamiento y prueba

# %%
# Guardar el DataFrame como un archivo CSV
df_income_pca.to_csv('df_train', index=False)

# %%
# Guardar el DataFrame como un archivo CSV
df_income_test_pca.to_csv('df_test', index=False)
